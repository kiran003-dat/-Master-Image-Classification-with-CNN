# %%
# !pip install keras_tuner
# Out:
# Collecting keras_tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in d:\anaconda\envs\myenv\lib\site-packages (from keras_tuner) (2.10.0)
# Requirement already satisfied: packaging in d:\anaconda\envs\myenv\lib\site-packages (from keras_tuner) (24.1)
# Requirement already satisfied: requests in d:\anaconda\envs\myenv\lib\site-packages (from keras_tuner) (2.32.3)
# Collecting kt-legacy (from keras_tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\envs\myenv\lib\site-packages (from requests->keras_tuner) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\envs\myenv\lib\site-packages (from requests->keras_tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\envs\myenv\lib\site-packages (from requests->keras_tuner) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\envs\myenv\lib\site-packages (from requests->keras_tuner) (2024.8.30)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras_tuner
# Successfully installed keras_tuner-1.4.7 kt-legacy-1.0.5
# WARNING: Ignoring invalid distribution -5py (d:\anaconda\envs\myenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -5py (d:\anaconda\envs\myenv\lib\site-packages)
# WARNING: Ignoring invalid distribution -5py (d:\anaconda\envs\myenv\lib\site-packages)

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 77s 0us/step

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(train_images[i], cmap = plt.cm.binary)
  plt.xlabel(class_names[train_labels[i][0]])
  plt.show()

# %%
def build_model(hp):
  model = models.Sequential()

  for i in range(hp.Int('conv_blocks', 1, 3)):
    if i == 0:
      model.add(layers.Conv2D(
           filters = hp.Int('filters_' + str(i), min_value = 32, max_value =128, step = 16),
           kernel_size = (3, 3),
           activation = 'relu',
           input_shape = (32, 32, 3)
      ))
    else:
        model.add(layers.Conv2D(
            filters = hp.Int('filters_' + str(i), min_value = 32, max_value =128, step = 16),
            kernel_size = (3, 3),
            activation = 'relu',
            padding = 'same'
        ))
  model.add(layers.MaxPooling2D(pool_size = (2, 2)))
  model.add(layers.Flatten())

  for i in range(hp.Int('dense_layers', 1, 3)):
    model.add(layers.Dense(
        units = hp.Int('units_' + str(i), min_value = 32, max_value = 128, step = 16),
        activation = 'relu'
    ))
    model.add(layers.Dropout(hp.Float('dropout_', min_value = 0.0, max_value = 0.5, step = 0.1)))

    model.add(layers.Dense(10, activation = 'softmax'))

    optimizer = tf.keras.optimizers.Adam(
        learning_rate = hp.Choice('learning_rate', values = [1e-2, 1e-3, 1e-4]))

    model.compile(
          optimizer = optimizer,
          loss = 'sparse_categorical_crossentropy',
          metrics = ['accuracy']
      )
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective = 'val_accuracy',
    max_trials = 10,
    executions_per_trial = 1,
    directory = 'output',
    project_name = 'CIFAR10_tunning'
)

tuner.search(train_images, train_labels, epochs = 10, validation_data = (test_images, test_labels))
best_hps = tuner.get_best_hyperparameters(num_trials = 1)[0]
model = tuner.hypermodel.build(best_hps)
history = model.fit(train_images, train_labels, epochs = 10, validation_data = (test_images, test_labels))

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.grid()

plt.tight_layout()
plt.show()
# Out:
# Trial 10 Complete [00h 02m 49s]
# val_accuracy: 0.6762999892234802
#
# Best val_accuracy So Far: 0.70660001039505
# Total elapsed time: 00h 22m 00s
# Epoch 1/10
# 1563/1563 [==============================] - 25s 15ms/step - loss: 1.6352 - accuracy: 0.4080 - val_loss: 1.3510 - val_accuracy: 0.5163
# Epoch 2/10
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.3323 - accuracy: 0.5246 - val_loss: 1.2153 - val_accuracy: 0.5690
# Epoch 3/10
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.1990 - accuracy: 0.5748 - val_loss: 1.0895 - val_accuracy: 0.6143
# Epoch 4/10
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.0964 - accuracy: 0.6145 - val_loss: 1.0685 - val_accuracy: 0.6247
# Epoch 5/10
# 1563/1563 [==============================] - 23s 14ms/step - loss: 1.0061 - accuracy: 0.6457 - val_loss: 1.0082 - val_accuracy: 0.6480
# Epoch 6/10
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.9313 - accuracy: 0.6738 - val_loss: 0.9470 - val_accuracy: 0.6648
# Epoch 7/10
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.8703 - accuracy: 0.6929 - val_loss: 0.9074 - val_accuracy: 0.6770
# Epoch 8/10
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.8104 - accuracy: 0.7178 - val_loss: 0.8904 - val_accuracy: 0.6866
# Epoch 9/10
# 1563/1563 [==============================] - 23s 14ms/step - loss: 0.7589 - accuracy: 0.7340 - val_loss: 0.8971 - val_accuracy: 0.6869
# Epoch 10/10
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.7179 - accuracy: 0.7512 - val_loss: 0.8827 - val_accuracy: 0.6963
